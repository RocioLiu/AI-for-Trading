# %% [markdown]
# <a id="table_of_content"></a>

# %% [markdown]
# # Part 1: Bag-of-Words Exercises
#
# In the following, we will convert our corpus of 10-k documents into bag-of-words, and convert them into document vectors using Term-Frequency-Inverse-Document-Frequency (tf-idf) re-weighting. Afterward, we will compute sentiments and similarity metrics. Since we will be reusing our notebook, so the various sections are linked below:
#
# 1. <a href="#bag_of_word">Compute bag-of-words </a>: implement `bag_of_words` that converts tokenized words into a dictionary of word-counts
#
# 2. <a href="#sentiment">Sentiments </a>: using wordlists, compute positive and negative sentiments from bag-of-words. Implement `get_sentiment`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`
#
# # Part 2: Document-Vector Exercises
#
# 3. <a href="#compute_idf">Compute idf </a>: computing the inverse document frequency, implement `get_idf`
#
# 4. <a href="#compute_tf">Compute tf </a>: computing the term frequency, implement `get_tf`
#
# 5. <a href="#doc_vector">Document vector </a>: using the functions `get_idf` and `get_tf`, compute a word_vector for each document in the corpus
# 6. <a href="#similarity">Similarities </a>: comparing two vectors, and compute cosine and jacard similarity metrics. Implement `get_cos` and `get_jac`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`

# %% [markdown]
# ## 0. Initialization
#
# First we read in our 10-k documents

# %%
# download some excerpts from 10-K files
from download10k import get_files

CIK = {'ebay': '0001065088', 'apple':'0000320193', 'sears': '0001310067'}
get_files(CIK['ebay'], 'EBAY')
get_files(CIK['apple'], 'AAPL')
get_files(CIK['sears'], 'SHLDQ')


# get a list of all 10-ks in our directory
files=! ls *10k*.txt
print("10-k files: ",files)
files = [open(f,"r").read() for f in files]
# Out:
# downloading 10-Ks item 1A for CIK = 0001065088 ...
# downloading 10-Ks item 1A for CIK = 0000320193 ...
# downloading 10-Ks item 1A for CIK = 0001310067 ...
# 10-k files:  ['AAPL_10k_2015.txt', 'AAPL_10k_2016.txt', 'AAPL_10k_2017.txt', 'AAPL_10k_2020.txt', 'EBAY_10k_2015.txt', 'EBAY_10k_2016.txt', 'EBAY_10k_2017.txt', 'SHLDQ_10k_2014.txt', 'SHLDQ_10k_2015.txt', 'SHLDQ_10k_2016.txt', 'SHLDQ_10k_2017.txt']

# %% [markdown]
# here we define useful functions to tokenize the texts into words, remove stop-words, and lemmatize and stem our words

# %%
import numpy as np

# for nice number printing
np.set_printoptions(precision=3, suppress=True)

# tokenize and clean the text
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from collections import Counter
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
# tokenize anything that is not a number and not a symbol
word_tokenizer = RegexpTokenizer(r'[^\d\W]+')

nltk.download('stopwords')
nltk.download('wordnet')


sno = SnowballStemmer('english')
wnl = WordNetLemmatizer()

# get our list of stop_words
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
# add some extra stopwords
stop_words |= {"may", "business", "company", "could", "service", "result", "product", 
               "operation", "include", "law", "tax", "change", "financial", "require",
               "cost", "market", "also", "user", "plan", "actual", "cash", "other",
               "thereto", "thereof", "therefore"}

# useful function to print a dictionary sorted by value (largest first by default)
def print_sorted(d, ascending=False):
    factor = 1 if ascending else -1
    sorted_list = sorted(d.items(), key=lambda v: factor*v[1])
    for i, v in sorted_list:
        print("{}: {:.3f}".format(i, v))

# convert text into bag-of-words
def clean_text(txt):
    lemm_txt = [ wnl.lemmatize(wnl.lemmatize(w.lower(),'n'),'v') \
                for w in word_tokenizer.tokenize(txt) if \
                w.isalpha() and w not in stop_words ]
    return [ sno.stem(w) for w in lemm_txt if w not in stop_words and len(w) > 2 ]

corpus = [clean_text(f) for f in files]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <a id="bag_of_words"></a>

# %% [markdown]
# ## 1. Bag-of-Words

# %% [markdown]
# Implement a function that converts a list of tokenized words into bag-of-words, i.e. a dictionary that outputs the frequency count of a word
#
# ** python already provide the `collections.Counter` class to perform this, but I encourage you to implement your own function as an exercise
#
# <a href="#table_of_content">back to top</a>

# %%
from collections import defaultdict

def bag_of_words(words):
    '''
    words: a list of words
    '''
    # TO DO
    bag = {}
    for w in words:
        bag[w] = bag.get(w, 0) + 1
            
    return bag


# def bag_of_words(words):
#     bag = defaultdict(int)
#     for w in words:
#         bag[w] += 1
#     return bag

# %% [markdown]
# <a id="sentiment"></a>

# %% [markdown]
# ## 2. Sentiments
# Count the fraction of words that appear in a wordlist, returning a sentiment score between 0 and 1:
#
# $$
# \textrm{score} = \frac{\textrm{Number of words in document matching wordlist}}{\textrm{Number of words in document}}
# $$
#
# Implement the score in a function `get_sentiment(words, wordlist)`, where words is a list of words. Feel free to use the previous `bag_of_words` function.
# (*for extra challenge, try to code the function in one-line*)
#
# Here, I've included a positive and negative wordlist that I constructed by hand. Due to copyright issues, we are not able to provide other commonly used wordlists. I encourage you to try out different wordlists on your own.
#
# <a href="#table_of_content">back to top</a>

# %%
# load wordlist first
import pickle

with open('positive_words.pickle', 'rb') as f:
    positive_words = pickle.load(f)
    # also need to stem and lemmatize the text
    positive_words = set(clean_text(" ".join(positive_words)))
    
with open('negative_words.pickle', 'rb') as f:
    negative_words = pickle.load(f)
    negative_words = set(clean_text(" ".join(negative_words)))
    
# check out the list
print("positive words: ", positive_words)
print()
print("negative words: ", negative_words)
# Out:
# positive words:  {'amaz', 'love', 'spring', 'brilliant', 'perfect', 'boon', 'divin', 'success', 'generous', 'resolv', 'eleg', 'favor', 'exquisit', 'refresh', 'boost', 'respect', 'incred', 'solv', 'flourish', 'fabul', 'fascin', 'compliment', 'except', 'abund', 'merit', 'exemplifi', 'devot', 'superb', 'actual', 'prestig', 'win', 'bliss', 'enchant', 'wealthi', 'surg', 'strong', 'clear', 'victori', 'delight', 'strength', 'wonder', 'succeed', 'pleasant', 'glamor', 'inspir', 'bolster', 'power', 'solut', 'talent', 'innov', 'nourish', 'fortun', 'outstand', 'promin', 'appeal', 'distinguish', 'legendari', 'upstand', 'trendi', 'good', 'transform', 'accept', 'exuber', 'lucrat', 'approv', 'rich', 'famous', 'winner', 'applaus', 'benefit', 'motiv', 'benevol', 'marvel', 'reward', 'booster', 'special', 'attract', 'courag', 'admir', 'optim', 'best', 'attain', 'elev', 'optimist', 'independ', 'bless', 'brighter', 'gift', 'great', 'stupend', 'championship', 'honor', 'buoy', 'champion', 'congratul', 'award', 'awesom', 'better', 'happi', 'visionari', 'resourc', 'heal', 'harmoni', 'earnest', 'accomplish', 'polish', 'opportun', 'lead', 'passion', 'revolutionari', 'enthusiasm', 'exhilar', 'ingeni', 'happili', 'astonish', 'beauti', 'loyalti', 'impress', 'prais', 'extraordinari', 'creativ', 'invent', 'endors', 'meritori', 'support', 'surmount', 'wow', 'groundbreak', 'persever', 'benefici', 'extraordinarili', 'fresh', 'growth', 'stabl', 'nobil', 'high', 'upbeat', 'effici', 'relief', 'acclaim', 'plenti', 'origin', 'distinct', 'ador', 'fantast', 'tremend', 'nobli', 'wholesom', 'dazzl', 'forefront', 'popular', 'amelior', 'restor', 'virtuous', 'appreci', 'outperform', 'esteem', 'prodigi', 'nurtur', 'profici', 'miracul', 'satisfactori', 'rebound', 'stabil', 'complet', 'enhanc', 'safe', 'recoveri', 'advanc', 'higher', 'improv', 'jubil', 'glow', 'cheer', 'master', 'benign', 'posit', 'trendili', 'bright', 'insight', 'miracl', 'terrif', 'vibrant', 'dynam', 'celebr', 'gain', 'laud', 'magic', 'wealth', 'belov', 'encourag', 'monument', 'loyal', 'enrich', 'nobl', 'adorn', 'reliev', 'revolution', 'surpass', 'effect', 'product', 'paradis', 'recov', 'flawless', 'prosper', 'prestigi', 'clean', 'achiev', 'excel', 'satisfi', 'reinforc', 'aptitud', 'command', 'progress', 'revolut'}
#
# negative words:  {'avoid', 'pollut', 'doom', 'insan', 'strike', 'imperil', 'unpopular', 'fire', 'disast', 'impedi', 'nuisanc', 'crash', 'termin', 'refus', 'unfruit', 'obstruct', 'harrow', 'vile', 'calam', 'hardship', 'obsolesc', 'declin', 'danger', 'disclaim', 'escal', 'cutback', 'impeach', 'disfavor', 'dysfunct', 'worsen', 'deplor', 'hazard', 'accident', 'distast', 'discourag', 'counterfeit', 'low', 'peril', 'crime', 'degrad', 'misappli', 'exploit', 'decept', 'ban', 'empti', 'unattract', 'ceas', 'distress', 'ugli', 'deplet', 'unproduct', 'powerless', 'apathi', 'breakabl', 'blow', 'aw', 'dread', 'invalid', 'scandal', 'disapprov', 'stress', 'apathet', 'indign', 'agoni', 'conflict', 'repuls', 'guilt', 'failur', 'murder', 'wast', 'imped', 'embezzl', 'vice', 'difficult', 'erron', 'impot', 'unstabl', 'arrest', 'trivial', 'litig', 'fraud', 'thiev', 'sue', 'jail', 'lower', 'rot', 'mockeri', 'retreat', 'illeg', 'horribl', 'abandon', 'burden', 'collud', 'hurt', 'ineffect', 'null', 'vilifi', 'intimid', 'objection', 'aggrav', 'underwhelm', 'troublesom', 'diminish', 'unworthi', 'defianc', 'harder', 'argu', 'object', 'indict', 'abhor', 'sacrific', 'close', 'terribl', 'nasti', 'fruitless', 'injuri', 'penalti', 'gruesom', 'sorrow', 'difficulti', 'unabl', 'desol', 'lie', 'downgrad', 'disinterest', 'malfunct', 'tragic', 'appal', 'demot', 'uneffect', 'insol', 'confus', 'investig', 'dark', 'illicit', 'delay', 'turbul', 'obsolet', 'cloudi', 'nullifi', 'attrit', 'collus', 'plung', 'blacklist', 'foul', 'disadvantag', 'fatal', 'balk', 'complic', 'deni', 'disabl', 'complaint', 'malign', 'unnecessarili', 'impoverish', 'woe', 'worst', 'forfeit', 'fault', 'accus', 'default', 'unneed', 'condemn', 'sacrifici', 'pessim', 'curs', 'shrink', 'trial', 'malic', 'disqualif', 'lazili', 'closur', 'notori', 'attenu', 'unfavor', 'loot', 'abnorm', 'outlaw', 'rotten', 'oppress', 'panic', 'defiant', 'unhappi', 'weak', 'shutdown', 'doubt', 'hamper', 'incompat', 'disturb', 'dirtili', 'insolv', 'terror', 'headach', 'atroci', 'hard', 'uninspir', 'frustrat', 'hostil', 'argument', 'harsher', 'gloom', 'inept', 'worri', 'underperform', 'devast', 'dissolv', 'urgent', 'imposs', 'bankrupt', 'conced', 'unsettl', 'guilti', 'manipul', 'cataclysm', 'scorn', 'renounc', 'death', 'fraudul', 'shadi', 'convict', 'horror', 'unfair', 'drain', 'crack', 'instabl', 'reject', 'contempt', 'content', 'negat', 'depress', 'halt', 'horrid', 'bottleneck', 'weari', 'flaw', 'doomsday', 'unattain', 'leak', 'repugn', 'dampen', 'falsifi', 'disregard', 'lazi', 'hinder', 'postpon', 'discredit', 'excess', 'misus', 'sever', 'misfortun', 'undermin', 'fright', 'temper', 'contradict', 'nastili', 'unauthor', 'illiquid', 'fail', 'unwelcom', 'untal', 'repudi', 'damag', 'dull', 'overpay', 'debt', 'pessimist', 'unfortun', 'troubl', 'abomin', 'harsh', 'dirti', 'gloomi', 'exhaust', 'offens', 'neglect', 'hate', 'bust', 'shame', 'threat', 'incident', 'destroy', 'accid', 'dead', 'tragedi', 'bankruptci', 'deprav', 'recal', 'miseri', 'desper', 'violat', 'plea', 'handicap', 'abhorr', 'break', 'lack', 'ridicul', 'vulgar', 'error', 'odious', 'breach', 'dismal', 'revolt', 'catastroph', 'deter', 'deterior', 'blame', 'deris', 'wors', 'bribe', 'suspend', 'worrisom', 'delus', 'hardest', 'unlaw', 'crisi', 'upset', 'lag', 'kill', 'wick', 'subpoena', 'injur', 'afflict', 'perjuri', 'boycott', 'thieveri', 'evil', 'horrend', 'ruin', 'misappl', 'fiasco', 'disqualifi', 'violent', 'devalu', 'lawsuit', 'uncontrol', 'steal', 'suspens', 'hatr', 'blackmail', 'disgust', 'erod', 'desist', 'usurp', 'exacerb', 'faulti', 'incid', 'taint', 'suspici', 'incap', 'wreck', 'slow', 'storm', 'inconveni', 'ineffici', 'inabl', 'untrustworthi', 'wrong', 'fear', 'uneth', 'anomali', 'forgeri', 'inviabl', 'corrupt', 'obnoxi', 'antiqu', 'unscrupul', 'inferior', 'fals', 'unnecessari', 'harm', 'weaken', 'strain', 'critic', 'pressur', 'eros', 'scourg', 'advers', 'nefari'}

# %%
def get_sentiment(txt, wordlist):
    '''
    txt: a list of words
    '''
    # TO DO

    score = len([w for w in txt if w in wordlist]) / len(txt)
    
    return score

# %%
# test your function
# Since the there're 11 files in the corpus, we can get a 11-dim array as output
positive_sentiments = np.array([ get_sentiment(c, positive_words) for c in corpus ])
print(positive_sentiments)

negative_sentiments = np.array([ get_sentiment(c, negative_words) for c in corpus ])
print(negative_sentiments)
# Out:
# [ 0.035  0.034  0.031  0.032  0.037  0.031  0.032  0.051  0.039  0.037
#   0.037]
# [ 0.055  0.06   0.053  0.059  0.058  0.061  0.061  0.063  0.062  0.06
#   0.058]

# %% [markdown]
# **before continuing part 2, go through the lesson material first!**

# %% [markdown]
# <a id="compute_idf"></a>

# %% [markdown]
# # Part 2 Document Vector Exercises
#
# ## 3. Computer idf
# Given a corpus, or a list of bag-of-words, we want to compute for each word $w$, the inverse-document-frequency, or ${\rm idf}(w)$. This can be done in a few steps:
#
# 1. Gather a set of all the words in all the bag-of-words (python set comes in handy, and the union operator `|` is useful here)
#
#
# 2. Loop over each word $w$, and compute ${\rm df}_w$, the number of documents where this word appears at least once. A dictionary is useful for keeping track of ${\rm df}_w$
#
#
# 3. After computing ${\rm df}_w$, we can compute ${\rm idf}(w)$. There are usually two possibilities, the simplest one is
# $${\rm idf}(w)=\frac{N}{{\rm df}_w}$$
# Where $N$ is the total number of documents in the corpus and $df_w$ the number of documents that contain the word $w$. Frequently, a logarithm term is added as well
# $${\rm idf}(w)=\log\frac{N}{{\rm df}_w}$$
# One issue with using the logarithm is that when ${\rm df}_w = N$, ${\rm idf}(w)=0$, indicating that words common to all documents would be ignored. If we don't want this behavior, we can define ${\rm idf}(w)=\log\left(1+N/{\rm df}_w\right)$ or ${\rm idf}(w)=1+\log\left(N/{\rm df}_w\right)$ instead. For us, we'll not use the extra +1 for ${\rm idf}$.
#
# In the following, define a function called `get_idf(corpus, include_log=True)` that computes ${\rm idf}(w)$ for all the words in a corpus, where `corpus` for us is a processed list of bag-of-words (stemmed and lemmatized). The optional parameter `include_log` includes the logarithm in the computation.
#
# <a href="#table_of_content">back to top</a>

# %%
# compute idf
def get_idf(corpus, include_log=True):
    '''
    corpus: A list of document which is a list of words
    '''
    # TO DO
    n = len(corpus)
    all_words = set()
    for c in corpus:
        all_words |= set(c)
    
    doc_freq = {}
    for w in all_words:
        doc_freq[w] = sum([w in c for c in corpus])
        
    if include_log:
        idf = {w: np.log(n / doc_freq[w]) for w in doc_freq}
    else:
        idf = {w: (n / doc_freq[w]) for w in doc_freq}
        
            
    return idf

# %% [markdown]
# You should expect to see many idf values = 0! This is by design, because we have ${\rm idf}(w)=\log N_d/{\rm df}_w$ and $N_d/{\rm df}_w=1$ for the most common words!

# %%
# test your code
idf=get_idf(corpus)
print_sorted(idf, ascending=True)
# Out:
# applic: 0.000
# manag: 0.000
# foreign: 0.000
# materi: 0.000
# good: 0.000
# involv: 0.000
# technolog: 0.000
# base: 0.000
# margin: 0.000
# ultim: 0.000
# litig: 0.000
# particular: 0.000
# militari: 0.000
# acquir: 0.000
# continu: 0.000
# way: 0.000
# increas: 0.000
# delay: 0.000
# personnel: 0.000
# differ: 0.000
# seek: 0.000
# anticip: 0.000
# often: 0.000
# cannot: 0.000
# lead: 0.000
# associ: 0.000
# success: 0.000
# retail: 0.000
# signific: 0.000
# rate: 0.000
# event: 0.000
# experi: 0.000
# depend: 0.000
# government: 0.000
# spend: 0.000
# acquisit: 0.000
# due: 0.000
# person: 0.000
# exchang: 0.000
# give: 0.000
# avail: 0.000
# varieti: 0.000
# one: 0.000
# abil: 0.000
# relat: 0.000
# advers: 0.000
# general: 0.000
# volatil: 0.000
# generat: 0.000
# declin: 0.000
# mani: 0.000
# reli: 0.000
# pend: 1.012
# trust: 1.012
# hour: 1.012
# look: 1.299
# reluct: 1.299
# dilig: 1.299
# ban: 1.299
# regim: 1.299
# defraud: 1.299
# languag: 1.299
# independ: 1.299
# pound: 1.299
# ireland: 1.299
# euro: 1.299
# maci: 1.299
# visibl: 1.299
# interfac: 1.299
# send: 1.299
# expend: 1.299
# privileg: 1.299
# gmbh: 1.299
# threshold: 1.299
# holder: 1.299
# clear: 1.299
# purport: 1.299
# former: 1.299
# circumv: 1.299
# vat: 1.299
# histori: 1.299
# com: 1.299
# mainten: 1.299
# unreli: 1.299
# officemax: 1.299
# dynam: 1.299
# multi: 1.299
# versus: 1.299
# british: 1.299
# outlook: 1.299
# neglig: 1.299
# sort: 1.299
# candid: 1.299
# indemnifi: 1.299
# qvc: 1.299
# late: 1.299
# come: 1.299
# amend: 1.299
# accid: 1.299
# warrant: 1.299
# calcul: 1.299
# negoti: 1.299
# octob: 1.299
# pii: 1.299
# revolv: 1.299
# engin: 1.299
# man: 1.299
# traffic: 1.299
# pricegrabb: 1.299
# fulfil: 1.299
# assum: 1.299
# absenc: 1.299
# job: 1.299
# faulti: 1.299
# lock: 1.299
# pawnbrok: 1.299
# inconveni: 1.299
# merchant: 1.299
# moral: 1.299
# univers: 1.299
# maker: 1.299
# remitt: 1.299
# august: 1.299
# prosecut: 1.299
# inquiri: 1.299
# malwar: 1.299
# reclaim: 1.299
# australian: 1.299
# list: 1.299
# llc: 1.299
# analyst: 1.299
# invas: 1.299
# raw: 1.299
# complain: 1.299
# amazon: 1.299
# pirat: 1.299
# ir: 1.299
# nuclear: 1.299
# accessori: 1.299
# mart: 1.299
# view: 1.299
# invent: 1.299
# depot: 1.299
# sue: 1.299
# america: 1.299
# omiss: 1.299
# elsewher: 1.299
# clarifi: 1.299
# ineffect: 1.299
# context: 1.299
# european: 1.299
# msn: 1.299
# libel: 1.299
# malfeas: 1.299
# search: 1.299
# freez: 1.299
# degre: 1.299
# will: 1.299
# prolong: 1.299
# cohes: 1.299
# god: 1.299
# simpler: 1.299
# antidump: 1.299
# complic: 1.299
# attribut: 1.299
# ever: 1.299
# reclam: 1.299
# set: 1.299
# revok: 1.299
# sabotag: 1.299
# strength: 1.299
# unusu: 1.299
# march: 1.299
# site: 1.299
# specifi: 1.299
# format: 1.299
# postpon: 1.299
# telephon: 1.299
# divert: 1.299
# host: 1.299
# discret: 1.299
# preclud: 1.299
# center: 1.299
# civil: 1.299
# foundat: 1.299
# suspend: 1.299
# rolex: 1.299
# wage: 1.299
# wal: 1.299
# notabl: 1.299
# paypal: 1.299
# nevertheless: 1.299
# discriminatori: 1.299
# contractu: 1.299
# putat: 1.299
# section: 1.299
# misappropri: 1.299
# campaign: 1.299
# status: 1.299
# sport: 1.299
# buyer: 1.299
# strike: 1.299
# cultur: 1.299
# react: 1.299
# dissemin: 1.299
# resid: 1.299
# array: 1.299
# meritori: 1.299
# dilut: 1.299
# fraud: 1.299
# kingdom: 1.299
# occurr: 1.299
# illeg: 1.299
# combat: 1.299
# compens: 1.299
# easili: 1.299
# sam: 1.299
# mail: 1.299
# unidentifi: 1.299
# second: 1.299
# advent: 1.299
# averag: 1.299
# switch: 1.299
# motiv: 1.299
# auction: 1.299
# obscen: 1.299
# penney: 1.299
# distanc: 1.299
# autom: 1.299
# plant: 1.299
# union: 1.299
# appear: 1.299
# protract: 1.299
# prove: 1.299
# light: 1.299
# disgorg: 1.299
# hors: 1.299
# drive: 1.299
# repeat: 1.299
# joint: 1.299
# decemb: 1.299
# indemnif: 1.299
# meaning: 1.299
# conting: 1.299
# unsettl: 1.299
# bug: 1.299
# unfair: 1.299
# speed: 1.299
# reduct: 1.299
# processor: 1.299
# shopzilla: 1.299
# border: 1.299
# back: 1.299
# counsel: 1.299
# moratorium: 1.299
# domain: 1.299
# denial: 1.299
# suit: 1.299
# spoof: 1.299
# resolut: 1.299
# translat: 1.299
# breadth: 1.299
# parallel: 1.299
# flat: 1.299
# yahoo: 1.299
# alway: 1.299
# entitl: 1.299
# unlaw: 1.299
# trojan: 1.299
# storefront: 1.299
# infrastructur: 1.299
# tiffani: 1.299
# vote: 1.299
# faster: 1.299
# profession: 1.299
# defam: 1.299
# sanction: 1.299
# warehous: 1.299
# deal: 1.299
# effici: 1.299
# satisfact: 1.299
# deem: 1.299
# contact: 1.299
# partnership: 1.299
# cross: 1.299
# ticket: 1.299
# hack: 1.299
# strong: 1.299
# absolut: 1.299
# issuer: 1.299
# disposit: 1.299
# induc: 1.299
# counterfeit: 1.299
# unsuccess: 1.299
# better: 1.299
# segment: 1.299
# indentur: 1.299
# ebay: 1.299
# persist: 1.299
# mitig: 1.299
# point: 1.299
# classifi: 1.299
# amort: 1.299
# streamlin: 1.299
# remov: 1.299
# messag: 1.299
# commenc: 1.299
# permit: 1.299
# sinc: 1.299
# stapl: 1.299
# longer: 1.299
# tool: 1.299
# license: 1.299
# intent: 1.299
# research: 1.299
# nextag: 1.299
# seller: 1.299
# korean: 1.299
# indian: 1.299
# per: 1.299
# princip: 1.299
# launch: 1.299
# licensur: 1.299
# vandal: 1.299
# penetr: 1.299
# nomin: 1.299
# revalu: 1.299
# leav: 1.299
# backlog: 1.299
# interchang: 1.299
# techniqu: 1.299
# watch: 1.299
# separ: 1.299
# secondhand: 1.299
# allow: 1.299
# input: 1.299
# match: 1.299
# offlin: 1.299
# juli: 1.299
# server: 1.299
# accrual: 1.299
# canada: 1.299
# indebted: 1.299
# threaten: 1.299
# costco: 1.299
# mac: 1.299
# downturn: 1.299
# impract: 1.299
# fundament: 1.299
# remit: 1.299
# februari: 1.299
# receipt: 1.299
# shorter: 1.299
# billion: 1.299
# put: 1.705
# decre: 1.705
# convert: 1.705
# christian: 1.705
# voic: 1.705
# overlap: 1.705
# distress: 1.705
# coutur: 1.705
# stabl: 1.705
# thailand: 1.705
# saturday: 1.705
# prosecutor: 1.705
# last: 1.705
# beaut: 1.705
# downgrad: 1.705
# loui: 1.705
# lesser: 1.705
# bear: 1.705
# anticompetit: 1.705
# bbb: 1.705
# thousand: 1.705
# previous: 1.705
# rest: 1.705
# surround: 1.705
# republ: 1.705
# lanco: 1.705
# tire: 1.705
# offici: 1.705
# cdnow: 2.398
# tower: 2.398
# substanc: 2.398
# nanett: 2.398
# realign: 2.398
# suprem: 2.398
# technician: 2.398
# merger: 2.398
# alcohol: 2.398
# best: 2.398
# bundl: 2.398
# famili: 2.398
# reit: 2.398
# factori: 2.398
# pharmaci: 2.398
# attorney: 2.398
# architectur: 2.398
# slow: 2.398
# presid: 2.398
# belong: 2.398
# complementari: 2.398
# quell: 2.398
# fiduciari: 2.398
# next: 2.398
# child: 2.398
# quarantin: 2.398
# drop: 2.398
# gasolin: 2.398
# refus: 2.398
# true: 2.398
# quill: 2.398
# taobao: 2.398
# pornograph: 2.398
# unattract: 2.398
# firepay: 2.398
# erron: 2.398
# arrest: 2.398
# mislead: 2.398
# verisign: 2.398
# arm: 2.398
# montr: 2.398
# secondari: 2.398
# lewi: 2.398
# preliminarili: 2.398
# burden: 2.398
# contamin: 2.398
# san: 2.398
# unintent: 2.398
# neighborhood: 2.398
# perfect: 2.398
# microprocessor: 2.398
# sender: 2.398
# tie: 2.398
# golden: 2.398
# travers: 2.398
# field: 2.398
# illicit: 2.398
# telephoni: 2.398
# kijiji: 2.398
# audienc: 2.398
# recruit: 2.398
# forum: 2.398
# aylwin: 2.398
# consign: 2.398
# desktop: 2.398
# singapor: 2.398
# disadvantag: 2.398
# quak: 2.398
# decompress: 2.398
# creativ: 2.398
# nochex: 2.398
# lump: 2.398
# lanham: 2.398
# mysimon: 2.398
# hear: 2.398
# santa: 2.398
# hyperwallet: 2.398
# columbia: 2.398
# leopard: 2.398
# fargo: 2.398
# interconnect: 2.398
# pleas: 2.398
# accommod: 2.398
# shortfal: 2.398
# swap: 2.398
# eight: 2.398
# rollout: 2.398
# auster: 2.398
# remand: 2.398
# unenforc: 2.398
# bmg: 2.398
# argument: 2.398
# summari: 2.398
# debat: 2.398
# submit: 2.398
# mention: 2.398
# worm: 2.398
# nand: 2.398
# flash: 2.398
# agre: 2.398
# incent: 2.398
# show: 2.398
# cryptographi: 2.398
# efficaci: 2.398
# restor: 2.398
# contrari: 2.398
# returnbuy: 2.398
# rout: 2.398
# weight: 2.398
# citi: 2.398
# master: 2.398
# entail: 2.398
# convey: 2.398
# uphold: 2.398
# inclus: 2.398
# philippin: 2.398
# ident: 2.398
# three: 2.398
# appeal: 2.398
# serious: 2.398
# intercept: 2.398
# player: 2.398
# sheet: 2.398
# freedom: 2.398
# dealtim: 2.398
# undistribut: 2.398
# visa: 2.398
# charl: 2.398
# creditor: 2.398
# prc: 2.398
# none: 2.398
# exacerb: 2.398
# vista: 2.398
# front: 2.398
# verifi: 2.398
# word: 2.398
# kind: 2.398
# frequenc: 2.398
# unnecessari: 2.398
# transmitt: 2.398
# suscept: 2.398
# paymat: 2.398

# %% [markdown]
# <a id="compute_tf"></a>

# %% [markdown]
# ## 4. Compute tf
#
# Below we will compute ${\rm tf}(w,d)$, or the term frequency for a given word $w$, in a given document $d$. Since our ultimate goal is to compute a document vector, we'd like to keep a few things in mind
#
# 1. Store the ${\rm tf}(w, d)$ for each word in a document as a dictionary
# 2. Even when a word doesn't appear in the document $d$, we still want to keep a $0$ entry in the dictionary. This is important when we convert the dictionary to a vector, where zero entries are important
#
#
# There are multiple definitions for ${\rm tf}(w,d)$, the simplest one is
#
# $$
# {\rm tf}(w,d)=\frac{f_{w,d}}{a_d}
# $$
#
# where $f_{w,d}$ is the number of occurence of the word $w$ in the document $d$, and $a$ the average occurence of all the words in that document for normalization. Just like ${\rm idf}(w)$, a logarithm can be added
#
# $$
# {\rm tf}(w,d)=\begin{cases}
# \frac{1+\log f_{w,d}}{1+\log a_d} & f_{w,d} > 0 \\
# 0 & f_{w,d} = 0 \\
# \end{cases}
# $$
#
# Implement the function `get_df(txt, include_log=True)` that computes ${\rm tf}(w,d)$ for each word in the document (returns a defaultdict(int), so that when supplying words not in the document the dictionary will yield zero instead of an error). Also include the optional parameter `include_log` that enables the additional logarithm term in the computation. I suggest also adding a function called `_tf` that computes the function above.
#
# <a href="#table_of_content">back to top</a>

# %%
import numpy as np
from math import *

def _tf(freq, avg, include_log=True):
    # TO DO
    if include_log:
        tf = 0 if freq == 0 else (1 + log(freq)) / (1 + log(avg))
    else:
        tf = freq / avg
        
    return tf


def get_tf(txt, include_log=True):
    '''
    txt: a list of words in a document
    '''
    # TO DO
    freq = bag_of_words(txt)
    avg = np.mean([v for v in freq.values()])
    #avg = np.mean(list(freq.values()))
    tf_dict = {w: _tf(f, avg, include_log) for w, f in freq.items()}
    
    return defaultdict(int, tf_dict)

# %%
tfs = [ get_tf(c) for c in corpus ]
print_sorted(tfs[0])
# Out:
# affect: 2.142
# oper: 2.113
# advers: 2.098
# condit: 2.090
# materi: 2.082
# develop: 1.939
# compon: 1.939
# price: 1.915
# third: 1.891
# parti: 1.864
# applic: 1.806
# certain: 1.806
# signific: 1.790
# risk: 1.790
# new: 1.790
# manufactur: 1.757
# softwar: 1.757
# continu: 1.739
# limit: 1.720
# futur: 1.701
# avail: 1.701
# current: 1.680
# addit: 1.680
# custom: 1.680
# subject: 1.680
# demand: 1.658
# time: 1.658
# foreign: 1.658
# sale: 1.636
# relat: 1.636
# effect: 1.612
# stock: 1.612
# distribut: 1.612
# assur: 1.612
# consum: 1.586
# valu: 1.586
# key: 1.586
# invest: 1.586
# competit: 1.586
# technolog: 1.586
# compet: 1.586
# margin: 1.586
# credit: 1.559
# devic: 1.559
# mani: 1.559
# provid: 1.559
# resel: 1.559
# retail: 1.559
# increas: 1.530
# mobil: 1.530
# communic: 1.530
# mac: 1.530
# substanti: 1.530
# iphon: 1.530
# content: 1.530
# manag: 1.530
# econom: 1.499
# depend: 1.499
# negat: 1.499
# system: 1.499
# industri: 1.499
# currenc: 1.499
# supplier: 1.499
# channel: 1.499
# comput: 1.499
# carrier: 1.499
# term: 1.499
# obtain: 1.465
# person: 1.465
# patent: 1.465
# network: 1.465
# regul: 1.465
# intern: 1.465
# perform: 1.429
# competitor: 1.429
# associ: 1.429
# inventori: 1.429
# store: 1.429
# uncertainti: 1.389
# global: 1.389
# sell: 1.389
# dollar: 1.389
# factor: 1.389
# failur: 1.389
# high: 1.389
# success: 1.389
# infring: 1.389
# base: 1.389
# use: 1.389
# consolid: 0.882
# equiti: 0.882
# follow: 0.882
# vari: 0.882
# realiz: 0.882
# charg: 0.882
# fair: 0.882
# overal: 0.882
# video: 0.882
# short: 0.882
# standard: 0.882
# adopt: 0.882
# uniqu: 0.882
# seek: 0.882
# line: 0.882
# larger: 0.882
# share: 0.882
# focus: 0.882
# within: 0.882
# upon: 0.882
# level: 0.882
# quantiti: 0.882
# meet: 0.882
# determin: 0.882
# write: 0.882
# exceed: 0.882
# excess: 0.882
# circumst: 0.882
# carri: 0.882
# occur: 0.882
# provis: 0.882
# build: 0.882
# announc: 0.882
# typic: 0.882
# respond: 0.882
# microprocessor: 0.882
# nand: 0.882
# flash: 0.882
# memori: 0.882
# dram: 0.882
# multipl: 0.882
# shortag: 0.882
# similar: 0.882
# compar: 0.882
# larg: 0.882
# often: 0.882
# whether: 0.882
# initi: 0.882
# concentr: 0.882
# contain: 0.882
# reput: 0.882
# final: 0.882
# ireland: 0.882
# china: 0.882
# disast: 0.882
# environment: 0.882
# polit: 0.882
# pay: 0.882
# distributor: 0.882
# varieti: 0.882
# legisl: 0.882
# find: 0.882
# extens: 0.882
# merit: 0.882
# fiscal: 0.882
# resolv: 0.882
# portfolio: 0.882
# settlement: 0.882
# decis: 0.882
# basi: 0.882
# respect: 0.882
# percept: 0.882
# benefit: 0.882
# leas: 0.882
# promot: 0.882
# unit: 0.882
# thus: 0.882
# aris: 0.882
# movement: 0.882
# earthquak: 0.882
# breach: 0.882
# furthermor: 0.882
# procedur: 0.882
# hedg: 0.882
# former: 0.882
# offic: 0.882
# examin: 0.882
# pose: 0.712
# spend: 0.712
# good: 0.712
# institut: 0.712
# increment: 0.712
# low: 0.712
# extrem: 0.712
# crisi: 0.712
# insolv: 0.712
# financ: 0.712
# interest: 0.712
# music: 0.712
# peripher: 0.712
# cut: 0.712
# frequent: 0.712
# life: 0.712
# near: 0.712
# research: 0.712
# hold: 0.712
# regist: 0.712
# appli: 0.712
# attract: 0.712
# advantag: 0.712
# stronger: 0.712
# intens: 0.712
# segment: 0.712
# educ: 0.712
# govern: 0.712
# author: 0.712
# maker: 0.712
# minor: 0.712
# technic: 0.712
# relationship: 0.712
# way: 0.712
# greater: 0.712
# subsidi: 0.712
# stimul: 0.712
# enhanc: 0.712
# ramp: 0.712
# appropri: 0.712
# stage: 0.712
# record: 0.712
# becom: 0.712
# net: 0.712
# necessari: 0.712
# cancel: 0.712
# fee: 0.712
# adequ: 0.712
# pace: 0.712
# incur: 0.712
# open: 0.712
# cover: 0.712
# forecast: 0.712
# insuffici: 0.712
# shift: 0.712
# wide: 0.712
# guarante: 0.712
# otherwis: 0.712
# incorpor: 0.712
# herein: 0.712
# percentag: 0.712
# item: 0.712
# common: 0.712
# evalu: 0.712
# need: 0.712
# capac: 0.712
# decid: 0.712
# complet: 0.712
# whole: 0.712
# much: 0.712
# conduct: 0.712
# unanticip: 0.712
# korea: 0.712
# critic: 0.712
# sole: 0.712
# germani: 0.712
# japan: 0.712
# itun: 0.712
# take: 0.712
# difficult: 0.712
# imposs: 0.712
# geograph: 0.712
# drm: 0.712
one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
def get_vector(tf, idf):
    # TO DO
    vec = np.array([tf[w] * idf[w] for w in idf])
    
    return vec

# %%
# test your code
doc_vectors = [ get_vector(tf, idf) for tf in tfs ]

for v in doc_vectors:
    print(v)
# Out:
# [ 0.     0.     0.19  ...,  0.281  0.432  0.   ]
# [ 0.     0.     0.319 ...,  0.279  0.428  0.   ]
# [ 0.     0.537  0.316 ...,  0.314  0.526  0.   ]
# [ 0.     0.     0.178 ...,  0.264  0.405  0.   ]
# [ 0.36   0.     0.161 ...,  0.238  0.     0.   ]
# [ 0.     0.47   0.39  ...,  0.322  0.219  0.483]
# [ 0.     0.466  0.386 ...,  0.319  0.217  0.478]
# [ 0.  0.  0. ...,  0.  0.  0.]
# [ 0.542  0.     0.    ...,  0.     0.     0.422]
# [ 0.529  0.     0.    ...,  0.     0.     0.412]
# [ 0.461  0.     0.    ...,  0.145  0.     0.753]

# %% [markdown]
# <a id ="similarity"></a>

# %% [markdown]
# ## 6. Similarity
#
# Given two word-vectors $\vec u$ (or $u_i$) and $\vec v$ (or $v_i$), corresponding to two documents, we want to compute different similarity metrics.
#
# 1. Cosine similarity, defined by
# $$
# {\rm Sim}_{\cos} = \frac{\vec u \cdot \vec v}{|\vec u| |\vec v|}
# $$
#
# 2. Jaccard similarity, defined by
# $$
# {\rm Sim}_{\rm Jaccard} = \frac{\sum_i \min\{u_i, v_i\}}{\sum_i \max\{u_i, v_i\}}
# $$
#
# Implement the function similarity as `sim_cis(u,v)` and `sim_jac(u,v)`. Utilize the numpy functions `numpy.linalg.norm` to compute norm of a vector and `np.dot` for computing dot-products. `np.minimum` and `np.maximum` are also useful vectorized pair-wise minimum and maximum functions.
#
# (*optional challenge: implement both functions in one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
from numpy.linalg import norm

def sim_cos(u,v):
    # TO DO
    sim_cos = np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
    
    return sim_cos


def sim_jac(u,v):
    # TO DO
    sim_jac = np.sum(np.minimum(u, v)) / np.sum(np.maximum(u, v))
    
    return sim_jac

# %%
# test your co
# compute all the pairwise similarity metrics
size = len(doc_vectors)
matrix_cos = np.zeros((size,size))
matrix_jac = np.zeros((size,size))

for i in range(size):
    for j in range(size):
        u = doc_vectors[i]
        v = doc_vectors[j]
        matrix_cos[i][j] = sim_cos(u,v)
        matrix_jac[i][j] = sim_jac(u,v)
        
print("Cosine Similarity:")
print(matrix_cos)

print()
print("Jaccard Similarity:")
print(matrix_jac)
# Out:
# Cosine Similarity:
# [[ 1.     0.579  0.485  0.375  0.146  0.14   0.143  0.034  0.04   0.032
#    0.071]
#  [ 0.579  1.     0.812  0.603  0.14   0.173  0.174  0.031  0.035  0.03
#    0.075]
#  [ 0.485  0.812  1.     0.704  0.136  0.179  0.183  0.032  0.034  0.031
#    0.08 ]
#  [ 0.375  0.603  0.704  1.     0.14   0.188  0.19   0.049  0.05   0.044
#    0.081]
#  [ 0.146  0.14   0.136  0.14   1.     0.362  0.367  0.046  0.062  0.056
#    0.14 ]
#  [ 0.14   0.173  0.179  0.188  0.362  1.     0.962  0.047  0.077  0.063
#    0.134]
#  [ 0.143  0.174  0.183  0.19   0.367  0.962  1.     0.048  0.078  0.065
#    0.136]
#  [ 0.034  0.031  0.032  0.049  0.046  0.047  0.048  1.     0.607  0.471
#    0.23 ]
#  [ 0.04   0.035  0.034  0.05   0.062  0.077  0.078  0.607  1.     0.783
#    0.366]
#  [ 0.032  0.03   0.031  0.044  0.056  0.063  0.065  0.471  0.783  1.     0.463]
#  [ 0.071  0.075  0.08   0.081  0.14   0.134  0.136  0.23   0.366  0.463  1.   ]]
#
# Jaccard Similarity:
# [[ 1.     0.493  0.414  0.32   0.109  0.128  0.128  0.032  0.04   0.039
#    0.08 ]
#  [ 0.493  1.     0.733  0.48   0.098  0.135  0.135  0.03   0.037  0.037
#    0.086]
#  [ 0.414  0.733  1.     0.571  0.099  0.142  0.143  0.031  0.036  0.038
#    0.088]
#  [ 0.32   0.48   0.571  1.     0.105  0.149  0.15   0.038  0.044  0.044
#    0.086]
#  [ 0.109  0.098  0.099  0.105  1.     0.255  0.258  0.023  0.03   0.031
#    0.089]
#  [ 0.128  0.135  0.142  0.149  0.255  1.     0.932  0.029  0.043  0.043
#    0.102]
#  [ 0.128  0.135  0.143  0.15   0.258  0.932  1.     0.03   0.044  0.044
#    0.103]
#  [ 0.032  0.03   0.031  0.038  0.023  0.029  0.03   1.     0.517  0.415
#    0.162]
#  [ 0.04   0.037  0.036  0.044  0.03   0.043  0.044  0.517  1.     0.756
#    0.236]
#  [ 0.039  0.037  0.038  0.044  0.031  0.043  0.044  0.415  0.756  1.     0.302]
#  [ 0.08   0.086  0.088  0.086  0.089  0.102  0.103  0.162  0.236  0.302  1.   ]]

# %% [markdown]
# ### Good Job! You've finished all the exercises!
#
# Here is an optional bonus challenge. We often need to debug other people's code to figure out what's wrong. It's particularly difficult when the code doesn't give errors but computes the wrong quantity. Can you describe why the following implementations for some of the exercises above may be wrong? Highlight the words at the bottom to reveal the solutions!

# %%
def get_idf_wrong(corpus, include_log=True):
    freq = defaultdict(int)
    for c in corpus:
        for w in c:
            freq[w] += 1
        
    N = len(corpus)
    if include_log:
        return { w:log(N/freq[w]) for w in freq }
    else:
        return { w:N/freq[w] for w in freq }


def get_sentiment_wrong(txt, wordlist):
    matching_words = [ w for w in wordlist if w in txt ]
    return len(matching_words)/len(txt)

def get_vectors_wrong(tf, idf):
    return np.array([ tf[w]*idf[w] for w in tf ])

# %% [markdown]
# # Solutions
#
# Drag your mouse over the white space below this cell, and you'll see details about the solutions.  Or, if it's easier, just double-click on the white space below this cell, which will reveal the cell with hidden text.  Also, please check out the file [bagofwords_solutions.py](bagofwords_solutions.py).

# %% [markdown]
# <font color="white">
# Solution
#
# get_idf: the defaultdict freq here computes the total number of occurences in all the document. We only want to count it once when a word appears in a document. This may lead to a document frequency larger than N, leading to a negative idf!
#
# get_sentiment_wrong: if a word w appears twice in the document, it won't be counted properly!
#
# get_vectors_wrong: tf may not contain all the words in idf. We need zero padding for words that appear in idf but not in tf!
# </font>
